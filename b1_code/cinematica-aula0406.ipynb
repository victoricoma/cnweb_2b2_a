# %% [markdown]
# <a href="https://colab.research.google.com/github/victoricoma/cnweb_2b2_a/blob/main/cinematica-aula0406.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fórmula da velocidade
# fonte: [https://www.todamateria.com.br/formulas-de-cinematica/]

# %%
def calculaVelMedia(deltaS, deltaT):
  velMedia = (deltaS/deltaT)
  return velMedia

# %% [markdown]
# ## Teste Serviço Nuvem: Velocidade Média

# %%
print("Vm=", calculaVelMedia(30, 15))
# Out:
# Vm= 2.0

# %% [markdown]
# # Fórmula da aceleração

# %% [markdown]
# # Fórmulas do Movimento Uniforme (MU)

# %% [markdown]
# # Função horária do deslocamento

# %%
def calculaDesloc(inicialS, deltaT, v):
  d = inicialS + (v*deltaT)
  return d

# %% [markdown]
# ## Testes de Função : Horária de Deslocamento

# %%
print("Deslocamento= ",calculaDesloc(0, 15, 30))
# Out:
# Deslocamento=  450

# %% [markdown]
# # Fórmulas do Movimento Uniformemente Variado (MUV)

# %%
def calMovimentoUniforme(vInicial, acel, tempo):
  vh = vInicial + (acel * tempo)
  return vh

# %% [markdown]
# ## Teste do Movimento Uniforme

# %%
print("Movimento Uniforme: ", calMovimentoUniforme(12, 25, 78), "ms")
# Out:
# Movimento Uniforme:  1962 ms

# %% [markdown]
# # Função horária da posição

# %%
def calcHorariaPosicao(pIni, pFin, vIn, a, t):

# %% [markdown]
# # Função horária da velocidade

# %% [markdown]
# # Equação de Torricelli

# %%
import math

def calTorricelli(vZero, acel, des):
  t=2*acel*des
  v=vZero+t
  res = round(math.sqrt(v), 2)
  return res

# %% [markdown]
# ## Testes de Torricelli

# %%
print("Calculo de Torricelli: ",calTorricelli(0,3,8))
# Out:
# Calculo de Torricelli:  6.93

# %% [markdown]
# # Fórmula do movimento vertical
